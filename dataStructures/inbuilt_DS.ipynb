# %% [markdown]
# # Inbuilt Data Structures
# *__list__* a collection of distinct types of values or items. /n
# The elements in the list are separated by using commas (,) and are surrounded by square brackets [].
# A single list can contain Datatypes such as Integers, Strings, and Objects.

# %%
list = [1, 2, 3, 4, 5]
list
# Out:
# [1, 2, 3, 4, 5]

# %%
dict = {'name':'Abhishek', 'dob':[4,2,2], 'email':'abhishek@gmail.com'}
dict
# Out:
# {'name': 'Abhishek', 'dob': [4, 2, 2], 'email': 'abhishek@gmail.com'}

# %%
tuple = (1, 2, 3, 4, 5)
tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
set = set([1, 2, 3, 'a', 'b', 5])
set
# Out:
# {1, 2, 3, 5, 'a', 'b'}

# %%
str = "My Name is Abhishek"
str
# Out:
# 'My Name is Abhishek'

# %%
bytearray = bytearray((1, 2, 3))
bytearray
# Out:
# bytearray(b'\x01\x02\x03')
